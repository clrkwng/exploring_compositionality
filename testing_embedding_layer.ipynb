# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import math

# %%
# g : R^2 -> R
# Here, each x \in X are \in R^2
def true_g(X):
    return np.sum(X, axis=1)
    # return np.sum(np.square(X), axis=1)
    # return np.where(np.linalg.norm(X, axis=1) < 4, 0, 1)

# Given g, each x \in X are \in R^3
def true_f(g, X):
    g_result = g(X[:,:2])
    return g_result * (1 - X[:,2]) + (10 * g_result) * X[:,2]

# %%
# Number of training points will be split_sizes[0] + split_sizes[1]
def get_train_data(split_sizes):
    n0 = split_sizes[0]
    n1 = split_sizes[1]

    X1_01 = np.around(np.random.uniform(0, 5, size=(n0,2)), 6)
    X1_2 = np.zeros((n0, 1))
    X1 = np.hstack((X1_01, X1_2))

    X2_01 = np.around(np.random.uniform(0, 5, size=(n1,2)), 6)
    X2_2 = np.ones((n1, 1))
    X2 = np.hstack((X2_01, X2_2))

    X_train = np.vstack((X1, X2))
    y_train = true_f(true_g, X_train)
    return X_train, y_train

X_train, y_train = get_train_data([5000,5000])
train_data = []
for i in range(len(X_train)):
    train_data.append([X_train[i], y_train[i]])

trainloader = torch.utils.data.DataLoader(train_data, shuffle=True, batch_size=20)

# %%
embedding = nn.Embedding(2,1)

# %%
with torch.no_grad():
    input = embedding(torch.from_numpy(X_train[:, 2]).long())

input = torch.from_numpy(X_train[:, 2]).long()

# %%
model = nn.Sequential(
    nn.Embedding(2,1),
    nn.LayerNorm(1),
    nn.Linear(1,1)
)

labels = torch.from_numpy(X_train[:,2]).unsqueeze(dim=1)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-6)
loss_values = []
num_epochs = 1000
for epoch in range(num_epochs):
    correct = 0
    optimizer.zero_grad()
    outputs = model(input)
    loss = criterion(outputs, labels)

    loss.backward(retain_graph=True)
    optimizer.step()
    
    output = (outputs > 0.5).float()
    correct += (output == labels).float().sum()

    acc = correct / len(train_data)
    print(f"Epoch {epoch}/{num_epochs}, Loss: {loss.item():.3f}, Accuracy: {acc:.3f}")
    loss_values.append(loss.item())

plt.plot(np.array(np.arange(0, num_epochs)), loss_values)
# Out:
# Epoch 0/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 1/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 2/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 3/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 4/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 5/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 6/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 7/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 8/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 9/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 10/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 11/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 12/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 13/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 14/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 15/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 16/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 17/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 18/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 19/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 20/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 21/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 22/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 23/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 24/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 25/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 26/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 27/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 28/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 29/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 30/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 31/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 32/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 33/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 34/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 35/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 36/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 37/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 38/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 39/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 40/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 41/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 42/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 43/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 44/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 45/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 46/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 47/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 48/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 49/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 50/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 51/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 52/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 53/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 54/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 55/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 56/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 57/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 58/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 59/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 60/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 61/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 62/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 63/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 64/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 65/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 66/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 67/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 68/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 69/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 70/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 71/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 72/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 73/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 74/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 75/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 76/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 77/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 78/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 79/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 80/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 81/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 82/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 83/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 84/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 85/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 86/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 87/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 88/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 89/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 90/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 91/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 92/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 93/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 94/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 95/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 96/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 97/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 98/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 99/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 100/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 101/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 102/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 103/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 104/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 105/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 106/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 107/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 108/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 109/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 110/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 111/1000, Loss: 0.731, Accuracy: 0.500
# Epoch 112/1000, Loss: 0.731, Accuracy: 0.500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-785661246d0d> in <module>
#      16     loss = criterion(outputs, labels)
#      17
# ---> 18     loss.backward(retain_graph=True)
#      19     optimizer.step()
#      20
#
# ~/miniconda2/envs/clark_test/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/miniconda2/envs/clark_test/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:
